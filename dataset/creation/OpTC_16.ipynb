# %% [markdown]
# <a href="https://www.kaggle.com/code/faihaj/optc-partially-corrected-dataset-creation?scriptVersionId=304348066" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !wget -L -O 2019-09-17.tar "https://entrepot.recherche.data.gouv.fr/api/access/datafile/:persistentId?persistentId=doi:10.57745/EG2WAI"
# Out:
# --2026-03-17 18:34:46--  https://entrepot.recherche.data.gouv.fr/api/access/datafile/:persistentId?persistentId=doi:10.57745/EG2WAI
# Resolving entrepot.recherche.data.gouv.fr (entrepot.recherche.data.gouv.fr)... 147.100.174.24
# Connecting to entrepot.recherche.data.gouv.fr (entrepot.recherche.data.gouv.fr)|147.100.174.24|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://prod-inria.opens3r-tls.stockage.inrae.fr/10.57745/UXCWOC/19bb7857f45-9f4528378518?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%272019-09-16.tar&response-content-type=application%2Fx-tar&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20260317T183448Z&X-Amz-SignedHeaders=host&X-Amz-Expires=14400&X-Amz-Credential=fe7774ae7b984cc58e9012f0d8d3531c%2F20260317%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=9375d8429b006d32a69d2558feccce5c16fb54d4d7679036c442ee282a6b94f5 [following]
# ...

# %%
from kaggle_secrets import UserSecretsClient
import os

user_secrets = UserSecretsClient()
os.environ['KAGGLE_USERNAME'] = user_secrets.get_secret("KAGGLE_USERNAME")
os.environ['KAGGLE_KEY'] = user_secrets.get_secret("KAGGLE_API_TOKEN")

# %%
# !kaggle datasets init -p /kaggle/working/
# Out:
# Data package template written to: /kaggle/working/dataset-metadata.json

# %%
import json
metadata = {
  "title": "A new hope for OpTC-ecar 16th september",
  "id": f"{os.environ['KAGGLE_USERNAME']}/json-a-new-hope-for-optc-sep16", 
  "licenses": [{"name": "MIT"}]
}
with open('/kaggle/working/dataset-metadata.json', 'w') as f:
    json.dump(metadata, f)

# %%
# !kaggle datasets create -p /kaggle/working/
# Out:
# Starting upload for file __notebook__.ipynb
# 100%|█████████████████████████████████████████| 938k/938k [00:01<00:00, 514kB/s]
# Upload successful: __notebook__.ipynb (938KB)
# Starting upload for file 2019-09-17.tar
# 100%|██████████████████████████████████████| 12.5G/12.5G [09:49<00:00, 22.8MB/s]
# Upload successful: 2019-09-17.tar (13GB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/faihaj/json-a-new-hope-for-optc-sep16
