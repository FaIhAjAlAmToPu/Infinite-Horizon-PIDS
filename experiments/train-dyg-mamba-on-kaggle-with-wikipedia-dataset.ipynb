# %%
# Installing the Wheel files
# !pip install /kaggle/input/datasets/faihaj/mamba-wheels/causal_conv1d-1.5.2+cu12torch2.4cxx11abiFALSE-cp311-cp311-linux_x86_64.whl
# !pip install /kaggle/input/datasets/faihaj/mamba-wheels/mamba_ssm-2.2.5+cu12torch2.4cxx11abiFALSE-cp311-cp311-linux_x86_64.whl
# Out:
# Processing /kaggle/input/datasets/faihaj/mamba-wheels/causal_conv1d-1.5.2+cu12torch2.4cxx11abiFALSE-cp311-cp311-linux_x86_64.whl
# ...
# Processing /kaggle/input/datasets/faihaj/mamba-wheels/mamba_ssm-2.2.5+cu12torch2.4cxx11abiFALSE-cp311-cp311-linux_x86_64.whl
# ...

# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/Infinite-Horizon-PIDS
# !git clone https://github.com/FaIhAjAlAmToPu/Infinite-Horizon-PIDS.git
# Out:
# /kaggle/working
# Cloning into 'Infinite-Horizon-PIDS'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 57 (delta 17), reused 49 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 3.57 MiB | 8.94 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# %cd /kaggle/working/Infinite-Horizon-PIDS/DyG-Mamba/DG_data
# Out:
# /kaggle/working/Infinite-Horizon-PIDS/DyG-Mamba/DG_data

# %%
# !wget https://zenodo.org/records/7213796/files/wikipedia.zip?download=1
# Out:
# --2026-03-13 11:05:43--  https://zenodo.org/records/7213796/files/wikipedia.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.52.235, 188.185.48.75, 188.184.103.118, ...
# Connecting to zenodo.org (zenodo.org)|137.138.52.235|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50208031 (48M) [application/octet-stream]
# Saving to: ‘wikipedia.zip?download=1’
#
# wikipedia.zip?downl 100%[===================>]  47.88M  16.2MB/s    in 2.9s
#
# 2026-03-13 11:05:46 (16.2 MB/s) - ‘wikipedia.zip?download=1’ saved [50208031/50208031]

# %%
# !unzip /kaggle/working/Infinite-Horizon-PIDS/DyG-Mamba/DG_data/wikipedia.zip?download=1
# Out:
# Archive:  /kaggle/working/Infinite-Horizon-PIDS/DyG-Mamba/DG_data/wikipedia.zip?download=1
#   inflating: wikipedia/ml_wikipedia.csv
#   inflating: wikipedia/ml_wikipedia.npy
#   inflating: wikipedia/ml_wikipedia_node.npy
#   inflating: wikipedia/wikipedia.csv

# %%
# !rm /kaggle/working/Infinite-Horizon-PIDS/DyG-Mamba/DG_data/wikipedia.zip?download=1

# %%
# %cd /kaggle/working/Infinite-Horizon-PIDS/DyG-Mamba/preprocess_data
# !python preprocess_data.py --dataset_name wikipedia
# Out:
# /kaggle/working/Infinite-Horizon-PIDS/DyG-Mamba/preprocess_data
# preprocess dataset wikipedia...
# number of nodes  9227
# number of node features  172
# number of edges  157474
# number of edge features  172
# wikipedia is processed successfully.
# wikipedia passes the checks successfully.

# %%
 # %cd /kaggle/working/Infinite-Horizon-PIDS/DyG-Mamba
# Out:
# /kaggle/working/Infinite-Horizon-PIDS/DyG-Mamba

# %%
# !python train_link_prediction.py --dataset_name wikipedia --model_name DyGMamba --gpu 0
# Out:
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 81029 interactions, involving 6141 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 12016 interactions, involving 2120 different nodes
# The new node test dataset has 11715 interactions, involving 2437 different nodes
# 922 nodes were used for the inductive testing, i.e. are never seen during training
# ModuleList(
#   (0-1): 2 x Block(
#     (mixer): MambaTimeDelta(
#       (in_proj): Linear(in_features=200, out_features=800, bias=False)
#       (conv1d): Conv1d(400, 400, kernel_size=(4,), stride=(1,), padding=(3,), groups=400)
#       (act): SiLU()
#       (x_proj): Linear(in_features=400, out_features=45, bias=False)
#       (dt_proj): Linear(in_features=13, out_features=400, bias=True)
# ...

# %%
# !python evaluate_link_prediction.py --dataset_name wikipedia --model_name DyGMamba --negative_sample_strategy random --gpu 0
# Out:
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 81029 interactions, involving 6141 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 12016 interactions, involving 2120 different nodes
# The new node test dataset has 11715 interactions, involving 2437 different nodes
# 922 nodes were used for the inductive testing, i.e. are never seen during training
# ModuleList(
#   (0-1): 2 x Block(
#     (mixer): MambaTimeDelta(
#       (in_proj): Linear(in_features=200, out_features=800, bias=False)
#       (conv1d): Conv1d(400, 400, kernel_size=(4,), stride=(1,), padding=(3,), groups=400)
#       (act): SiLU()
#       (x_proj): Linear(in_features=400, out_features=45, bias=False)
#       (dt_proj): Linear(in_features=13, out_features=400, bias=True)
# ...
