# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("GITHUB_EMAIL")
secret_value_1 = user_secrets.get_secret("GITHUB_PAT")
secret_value_2 = user_secrets.get_secret("GITHUB_USERNAME")

# %%
my_repo_name = "Infinite-Horizon-PIDS" 

# Format: https://USERNAME:PAT@github.com/USERNAME/REPO.git
auth_url = f"https://{secret_value_2}:{secret_value_1}@github.com/{secret_value_2}/{my_repo_name}.git"

# %%
# !git clone $auth_url
# Out:
# Cloning into 'Infinite-Horizon-PIDS'...
# ...

# %%
# !git clone https://github.com/Clearloveyuan/DyG-Mamba.git
# !rm -rf /kaggle/working/DyG-Mamba/.git
# Out:
# Cloning into 'DyG-Mamba'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 118 (delta 48), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (118/118), 3.74 MiB | 21.51 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# !mv /kaggle/working/DyG-Mamba Infinite-Horizon-PIDS/DyG-Mamb

# %%
# %cd /kaggle/working/Infinite-Horizon-PIDS
# Out:
# /kaggle/working/Infinite-Horizon-PIDS

# %%
# !git config user.email $secret_value_0
# !git config user.name $secret_value_2

# %%
# !git add .

# Your first commit
# !git commit -m "Initial commit: Building Infinite-Horizon-PIDS on DyG-Mamba base"

# !git push origin main
# Out:
# [main (root-commit) 40834c1] Initial commit: Building Infinite-Horizon-PIDS on DyG-Mamba base
#  31 files changed, 9173 insertions(+)
#  create mode 100644 DyG-Mamb/DG_data/DATASETS_README.md
#  create mode 100644 DyG-Mamb/Dyg-Mamba.jpg
#  create mode 100644 DyG-Mamb/Performance-1.png
#  create mode 100644 DyG-Mamb/Performance-2.png
#  create mode 100644 DyG-Mamb/README.md
#  create mode 100644 DyG-Mamb/evaluate_link_prediction.py
#  create mode 100644 DyG-Mamb/evaluate_link_prediction_robustness_test.py
#  create mode 100644 DyG-Mamb/evaluate_models_utils.py
#  create mode 100644 DyG-Mamb/evaluate_node_classification.py
#  create mode 100644 DyG-Mamb/models/CAWN.py
#  create mode 100644 DyG-Mamb/models/DyGFormer.py
#  create mode 100644 DyG-Mamb/models/DyGMamba.py
#  create mode 100644 DyG-Mamb/models/EdgeBank.py
#  create mode 100644 DyG-Mamb/models/FreeDyG.py
#  create mode 100644 DyG-Mamb/models/GraphMixer.py
#  create mode 100644 DyG-Mamb/models/MemoryModel.py
# ...

# %%
# The pytorch version 2.4 is mostly tested for mamba_ssm Library so Downgrading default Pytorch version
# !pip install torch==2.4.1 torchvision==0.19.1 torchaudio==2.4.1 --index-url https://download.pytorch.org/whl/cu124

# %%
# Based on the GPU requriments of Kaggle and Pytorch version, downloading the appropriate Wheel files
# !wget https://github.com/Dao-AILab/causal-conv1d/releases/download/v1.5.2/causal_conv1d-1.5.2+cu12torch2.4cxx11abiFALSE-cp311-cp311-linux_x86_64.whl

# !wget https://github.com/state-spaces/mamba/releases/download/v2.2.5/mamba_ssm-2.2.5+cu12torch2.4cxx11abiFALSE-cp311-cp311-linux_x86_64.whl

# %%
# Installing the Wheel files
# !pip install /kaggle/working/causal_conv1d-1.5.2+cu12torch2.4cxx11abiFALSE-cp311-cp311-linux_x86_64.whl
# !pip install /kaggle/working/mamba_ssm-2.2.5+cu12torch2.4cxx11abiFALSE-cp311-cp311-linux_x86_64.whl

# %%
# %cd DG_data

# %%
# !wget https://zenodo.org/records/7213796/files/wikipedia.zip?download=1

# %%
# !unzip /kaggle/working/DyG-Mamba/DG_data/wikipedia.zip?download=1

# %%
# !rm /kaggle/working/DyG-Mamba/DG_data/DATASETS_README.md
# !rm /kaggle/working/DyG-Mamba/DG_data/wikipedia.zip?download=1

# %%
# %cd ../preprocess_data
# !python preprocess_data.py --dataset_name wikipedia

# %%
 # %cd ..

# %%
# !python train_link_prediction.py --dataset_name wikipedia --model_name DyGMamba --gpu 0
